# %% [markdown]
# ## Benders Decomp
#
# $\theta$ represents to cost of assigning location i to facility j
#
# ## Objective Function
# $$
# \min \sum_{j \in N} f_j y_j + \sum_{i \in N} \theta_i
# $$
#
#
# ### Inital Problem (Open atleast 1 facility)
# $$
# s.t. \sum_{j \in N} \geq 1
# $$
#
# $$
# \theta_i \geq \min_{j \in N} \{c_{ij}\} \forall i \in N
# $$
#
# ### Solve (Assign it to the closest Open facility)
# $$
# \Theta_i (y^*) = \min_{j \in N | y^*_i = 1} c_{ij}
# $$
#
# $$
# \theta_i \geq \Theta_i(y^*) - \sum_{j \in N | c_{ij} < \Theta_i (y^*)} (\Theta_i (y^*) - c_{ij})
# $$

# %%
import math
import random
import gurobipy as gp

EPS = 1e-6

random.seed(3)

nLocs = 300
I = range(nLocs)
J = range(nLocs)
F = [random.randint(10000,20000) for i in I]
C = [[random.randint(1000,2000) for j in J] for i in I]

m = gp.Model()

# Vars
Y = {j: m.addVar(vtype=gp.GRB.BINARY) for j in J}
Theta = {i: m.addVar(lb=min(C[i])) for i in I}

OpenAtLeastOne = m.addConstr(gp.quicksum(Y.values()) >= 1)

m.setObjective(
    gp.quicksum(F[j] * Y[j] for j in J)
    + gp.quicksum(Theta.values())
)

for k in range(10):
    m.optimize() 

    # Set of open facilities
    FSet = {j for j in J if round(Y[j].x)==1}

    # Cost of opening things and the cost of assigning things
    UpperBound = sum(F[j] for j in FSet)
    
    CutsAdded = 0
    for i in I:
        cMin = min(C[i][j] for j in FSet)
        UpperBound += cMin
        if cMin > Theta[i].x + EPS:
            CutsAdded += 1
            # Increase theta to atleast this cost unless we open a facility that is closer
            m.addConstr(
                Theta[i] >= cMin - gp.quicksum(
                    (cMin - C[i][j]) * Y[j] 
                    for j in J
                    if C[i][j] < cMin
                )
            )
    print('*' * 50)
    print(k, CutsAdded, round(m.ObjVal),  UpperBound, FSet)
    print('*' * 50)
# Out:
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1 rows, 600 columns and 300 nonzeros
# Model fingerprint: 0x460e0c0d
# Variable types: 300 continuous, 300 integer (300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 312790.00000
# Presolve removed 1 rows and 600 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 310778 312790
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.107780000000e+05, best bound 3.107780000000e+05, gap 0.0000%
# **************************************************
# 0 299 310778 456436 {295}
# **************************************************
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 300 rows, 600 columns and 44458 nonzeros
# Model fingerprint: 0xb19aaab3
# Variable types: 300 continuous, 300 integer (300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 2e+03]
#
# MIP start from previous solve produced solution with objective 456436 (0.00s)
# Loaded MIP start from previous solve with objective 456436
#
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.02s
# Presolved: 300 rows, 599 columns, 44458 nonzeros
# Variable types: 0 continuous, 599 integer (300 binary)
#
# Root relaxation: objective 3.508677e+05, 385 iterations, 0.01 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 350867.719    0  180 456436.000 350867.719  23.1%     -    0s
# H    0     0                    409607.00000 350867.719  14.3%     -    0s
# H    0     0                    408596.00000 350867.719  14.1%     -    0s
# H    0     0                    385800.00000 350867.719  9.05%     -    0s
# H    0     0                    378159.00000 350867.719  7.22%     -    0s
# H    0     0                    368721.00000 350867.719  4.84%     -    0s
# H    0     0                    366702.00000 350867.719  4.32%     -    0s
# H    0     0                    364275.00000 350867.719  3.68%     -    0s
#      0     0 352298.242    0  214 364275.000 352298.242  3.29%     -    0s
#      0     0 371494.811    0  330 387799.000 371494.811  4.20%     -    0s
#      0     0 371494.811    0  330 387799.000 371494.811  4.20%     -    0s
#      0     0 372653.552    0  334 387799.000 372653.552  3.91%     -    0s
# H    0     0                    383919.00000 372653.552  2.93%     -    0s
# H    0     0                    383910.00000 372653.552  2.93%     -    0s
# H    0     0                    381641.00000 372653.552  2.35%     -    0s
#      0     0 372736.331    0  333 381641.000 372736.331  2.33%     -    0s
#      0     0 372736.331    0  331 381641.000 372736.331  2.33%     -    0s
#      0     0 372736.331    0  330 381641.000 372736.331  2.33%     -    0s
#      0     0 373634.474    0  332 381641.000 373634.474  2.10%     -    0s
#      0     2 373646.113    0  332 381641.000 373646.113  2.09%     -    0s
# H   30    56                    381640.00000 373646.113  2.09%   105    0s
# H   48    56                    381638.00000 373646.113  2.09%  77.6    0s
# H   55    93                    381562.00000 373646.113  2.07%  73.2    0s
# H   92   115                    381561.00000 373646.113  2.07%  61.2    0s
# H   92   115                    381560.00000 373646.113  2.07%  61.2    0s
# H  114   163                    381442.00000 373646.113  2.04%  56.0    0s
# H  310   321                    381242.00000 373646.113  1.99%  49.3    0s
# H  850   766                    381238.00000 373646.113  1.99%  52.0    1s
# H  866   797                    381147.00000 373646.113  1.97%  52.0    1s
# H 1347  1049                    380658.00000 373646.113  1.84%  50.0    1s
# H 9013  1799                    379886.00000 377925.262  0.52%  47.2    4s
# * 9130  1172              22    379592.00000 378054.110  0.41%  47.2    4s
#
# Cutting planes:
#   MIR: 53
#   StrongCG: 3
#
# Explored 11003 nodes (482274 simplex iterations) in 4.69 seconds (12.47 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 379592 379886 380658 ... 381562
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.795920000000e+05, best bound 3.795920000000e+05, gap 0.0000%
# **************************************************
# 3 118 379592 391027 {259, 140, 227, 84}
# **************************************************
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 826 rows, 600 columns and 77145 nonzeros
# Model fingerprint: 0x7fc7003c
# Variable types: 300 continuous, 300 integer (300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 2e+03]
#
# MIP start from previous solve produced solution with objective 391027 (0.00s)
# Loaded MIP start from previous solve with objective 391027
#
# Presolve removed 3 rows and 0 columns
# Presolve time: 0.05s
# Presolved: 823 rows, 600 columns, 77139 nonzeros
# Variable types: 0 continuous, 600 integer (300 binary)
#
# Root relaxation: objective 3.730475e+05, 727 iterations, 0.03 seconds (0.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 373047.549    0  328 391027.000 373047.549  4.60%     -    0s
# H    0     0                    390730.00000 373047.549  4.53%     -    0s
# H    0     0                    390682.00000 373047.549  4.51%     -    0s
#      0     0 373770.694    0  329 390682.000 373770.694  4.33%     -    0s
# H    0     0                    384638.00000 373770.694  2.83%     -    0s
#      0     0 374095.236    0  331 384638.000 374095.236  2.74%     -    0s
#      0     0 374095.236    0  329 384638.000 374095.236  2.74%     -    0s
#      0     0 374095.236    0  329 384638.000 374095.236  2.74%     -    0s
#      0     0 374095.236    0  332 384638.000 374095.236  2.74%     -    0s
#      0     0 374462.900    0  330 384638.000 374462.900  2.65%     -    0s
# H    0     0                    384635.00000 374462.900  2.64%     -    0s
# H    0     0                    384494.00000 374462.900  2.61%     -    0s
#      0     0 374574.829    0  330 384494.000 374574.829  2.58%     -    0s
# H   53    61                    387776.00000 377352.482  2.69%   103    1s
# H   53    61                    387770.00000 377352.482  2.69%   103    1s
# H   60    98                    387188.00000 377352.482  2.54%  96.6    1s
# H  595   562                    386604.00000 377352.482  2.39%  62.3    1s
#   2541  1824 380032.573   20  312 386604.000 379752.381  1.77%  67.7    5s
# *14969  2655              27    386567.00000 384996.346  0.41%  66.6    9s
#  16280  1515     cutoff   44      386567.000 385696.278  0.23%  65.3   10s
# *16330  1320              31    386346.00000 385696.278  0.17%  65.2   10s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 32
#   StrongCG: 1
#
# Explored 18385 nodes (1109529 simplex iterations) in 10.20 seconds (30.97 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 386346 386567 386604 ... 389255
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.863460000000e+05, best bound 3.863460000000e+05, gap 0.0000%
# **************************************************
# 6 123 386346 396088 {266, 26, 91, 173}
# **************************************************
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1137 rows, 600 columns and 99785 nonzeros
# Model fingerprint: 0x2f8ed06e
# Variable types: 300 continuous, 300 integer (300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 2e+03]
#
# MIP start from previous solve produced solution with objective 396088 (0.01s)
# Loaded MIP start from previous solve with objective 396088
#
# Presolve time: 0.05s
# Presolved: 1137 rows, 600 columns, 99785 nonzeros
# Variable types: 0 continuous, 600 integer (300 binary)
#
# Root relaxation: objective 3.763110e+05, 944 iterations, 0.05 seconds (0.15 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 376311.016    0  345 396088.000 376311.016  4.99%     -    0s
# H    0     0                    395728.00000 376311.016  4.91%     -    0s
#      0     0 376457.119    0  344 395728.000 376457.119  4.87%     -    0s
# H    0     0                    393709.00000 376457.119  4.38%     -    0s
# H    0     0                    393708.00000 376457.119  4.38%     -    0s
# H    0     0                    393706.00000 376457.119  4.38%     -    0s
# H    0     0                    393614.00000 376457.119  4.36%     -    0s
#      0     0 376746.198    0  344 393614.000 376746.198  4.29%     -    0s
#      0     0 376746.198    0  344 393614.000 376746.198  4.29%     -    0s
#      0     0 376746.198    0  345 393614.000 376746.198  4.29%     -    0s
#      0     0 377130.490    0  345 393614.000 377130.490  4.19%     -    0s
#      0     0 377130.490    0  346 393614.000 377130.490  4.19%     -    0s
#      0     0 377138.848    0  346 393614.000 377138.848  4.19%     -    0s
#      0     0 377138.848    0  346 393614.000 377138.848  4.19%     -    0s
#      0     0 377716.926    0  346 393614.000 377716.926  4.04%     -    0s
#      0     0 377758.372    0  345 393614.000 377758.372  4.03%     -    0s
#      0     0 378053.199    0  344 393614.000 378053.199  3.95%     -    0s
# H    0     0                    393611.00000 378053.199  3.95%     -    1s
# H    0     0                    392665.00000 378053.199  3.72%     -    1s
#      0     2 378053.199    0  344 392665.000 378053.199  3.72%     -    1s
# H   29    58                    392662.00000 378053.199  3.72%   162    1s
# H   35    58                    392038.00000 378053.199  3.57%   141    1s
# H   35    58                    390660.00000 378053.199  3.23%   141    1s
# H   57    95                    390019.00000 378053.199  3.07%   105    1s
# H  308   302                    388383.00000 378053.199  2.66%  74.3    1s
#   2008  1658 384315.178    7  345 388383.000 378571.601  2.53%  70.7    5s
# H 2513  1779                    387449.00000 378675.388  2.26%  81.3    6s
#  11123    14     cutoff   32      387449.000 386554.933  0.23%  68.7   10s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 34
#
# Explored 11304 nodes (770034 simplex iterations) in 10.18 seconds (31.96 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 387449 388383 390019 ... 393706
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.874490000000e+05, best bound 3.874490000000e+05, gap 0.0000%
# **************************************************
# 7 40 387449 390587 {32, 298, 140, 246}
# **************************************************
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1177 rows, 600 columns and 103836 nonzeros
# Model fingerprint: 0x687d3b99
# Variable types: 300 continuous, 300 integer (300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 2e+03]
#
# MIP start from previous solve produced solution with objective 390587 (0.01s)
# Loaded MIP start from previous solve with objective 390587
#
# Presolve time: 0.05s
# Presolved: 1177 rows, 600 columns, 103836 nonzeros
# Variable types: 0 continuous, 600 integer (300 binary)
#
# Root relaxation: objective 3.763565e+05, 965 iterations, 0.05 seconds (0.16 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 376356.494    0  344 390587.000 376356.494  3.64%     -    0s
#      0     0 376489.157    0  343 390587.000 376489.157  3.61%     -    0s
#      0     0 376693.699    0  345 390587.000 376693.699  3.56%     -    0s
#      0     0 376693.699    0  345 390587.000 376693.699  3.56%     -    0s
#      0     0 376693.699    0  346 390587.000 376693.699  3.56%     -    0s
#      0     0 377089.107    0  346 390587.000 377089.107  3.46%     -    0s
#      0     0 377148.071    0  346 390587.000 377148.071  3.44%     -    0s
#      0     0 377148.071    0  346 390587.000 377148.071  3.44%     -    0s
#      0     0 377149.034    0  346 390587.000 377149.034  3.44%     -    0s
#      0     0 377578.374    0  344 390587.000 377578.374  3.33%     -    0s
#      0     0 377606.239    0  344 390587.000 377606.239  3.32%     -    0s
#      0     0 377606.239    0  343 390587.000 377606.239  3.32%     -    0s
#      0     0 377606.239    0  344 390587.000 377606.239  3.32%     -    0s
#      0     0 377606.239    0  346 390587.000 377606.239  3.32%     -    0s
#      0     0 377606.239    0  346 390587.000 377606.239  3.32%     -    0s
#      0     0 378309.302    0  346 390587.000 378309.302  3.14%     -    1s
#      0     2 378427.799    0  346 390587.000 378427.799  3.11%     -    1s
# H   51    73                    390302.00000 378427.799  3.04%   128    1s
# *   87    99              11    389802.00000 378427.799  2.92%   101    1s
# H  276   267                    389754.00000 378427.799  2.91%  86.2    1s
#   2115  1853 379613.112   19  346 389754.000 379613.112  2.60%  73.8    5s
# H 2256  1824                    389376.00000 379613.112  2.51%  78.2    5s
# H 2554  1846                    389261.00000 379613.112  2.48%  84.5    6s
# *13633  7304              35    389094.00000 384546.092  1.17%  68.0    9s
#  14151  7482 387617.378   55  292 389094.000 384672.734  1.14%  67.4   10s
# *14845  5552              27    388492.00000 384755.257  0.96%  66.8   10s
# *20037  4709              24    388418.00000 386659.798  0.45%  71.1   12s
# *20971  2821              25    388104.00000 386991.709  0.29%  71.7   12s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 31
#
# Explored 24451 nodes (1607045 simplex iterations) in 13.13 seconds (41.56 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 388104 388418 388492 ... 390587
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.881040000000e+05, best bound 3.881040000000e+05, gap 0.0000%
# **************************************************
# 8 88 388104 393668 {259, 81, 27, 70}
# **************************************************
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1265 rows, 600 columns and 110344 nonzeros
# Model fingerprint: 0x2544bcbc
# Variable types: 300 continuous, 300 integer (300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 2e+03]
#
# MIP start from previous solve produced solution with objective 393668 (0.01s)
# Loaded MIP start from previous solve with objective 393668
#
# Presolve time: 0.06s
# Presolved: 1265 rows, 600 columns, 110344 nonzeros
# Variable types: 0 continuous, 600 integer (300 binary)
#
# Root relaxation: objective 3.769026e+05, 1018 iterations, 0.05 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 376902.584    0  341 393668.000 376902.584  4.26%     -    0s
#      0     0 377035.350    0  343 393668.000 377035.350  4.23%     -    0s
# H    0     0                    391044.00000 377035.350  3.58%     -    0s
#      0     0 377309.446    0  342 391044.000 377309.446  3.51%     -    0s
#      0     0 377309.446    0  342 391044.000 377309.446  3.51%     -    0s
#      0     0 377309.446    0  342 391044.000 377309.446  3.51%     -    0s
#      0     0 377744.833    0  343 391044.000 377744.833  3.40%     -    0s
#      0     0 377744.833    0  342 391044.000 377744.833  3.40%     -    0s
#      0     0 377878.788    0  343 391044.000 377878.788  3.37%     -    0s
#      0     0 377878.788    0  344 391044.000 377878.788  3.37%     -    0s
#      0     0 378239.991    0  344 391044.000 378239.991  3.27%     -    1s
#      0     0 378611.950    0  344 391044.000 378611.950  3.18%     -    1s
#      0     2 378611.950    0  344 391044.000 378611.950  3.18%     -    1s
# H  162   164                    389705.00000 378611.950  2.85%  95.9    1s
# H  165   181                    389673.00000 378611.950  2.84%  96.0    1s
# H  218   219                    388779.00000 378611.950  2.62%  91.9    1s
#   2586  1829 388437.017   63  344 388779.000 379469.136  2.39%  83.9    6s
#   6658  2519 385372.567   74  343 388779.000 383848.131  1.27%  91.4   10s
# * 9365  2556              21    388726.00000 385534.581  0.82%  91.1   11s
#
# Cutting planes:
#   MIR: 35
#
# Explored 14967 nodes (1200824 simplex iterations) in 12.90 seconds (41.73 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 388726 388779 389673 ... 393668
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.887260000000e+05, best bound 3.887260000000e+05, gap 0.0000%
# **************************************************
# 9 21 388726 390137 {184, 298, 259, 140}
# **************************************************

# %%
import math
import random
import gurobipy as gp

EPS = 1e-6

random.seed(3)

nLocs = 300
I = range(nLocs)
J = range(nLocs)
F = [random.randint(10000,20000) for i in I]
C = [[random.randint(1000,2000) for j in J] for i in I]

m = gp.Model()

# Vars
Y = {j: m.addVar(vtype=gp.GRB.BINARY) for j in J}
Theta = {i: m.addVar(lb=min(C[i])) for i in I}

OpenAtLeastOne = m.addConstr(gp.quicksum(Y.values()) >= 1)

m.setObjective(
    gp.quicksum(F[j] * Y[j] for j in J)
    + gp.quicksum(Theta.values())
)

def Callback(model, where):
    if where == gp.GRB.Callback.MIPSOL:
        YV = model.cbGetSolution(Y)
        ThetaV = model.cbGetSolution(Theta)


        # Set of open facilities
        FSet = {j for j in J if round(YV[j])==1}

        # Cost of opening things and the cost of assigning things
        UpperBound = sum(F[j] for j in FSet)
        
        CutsAdded = 0
        for i in I:
            cMin = min(C[i][j] for j in FSet)
            UpperBound += cMin
            if cMin > ThetaV[i] + EPS:
                ThetaV[i] = cMin
                CutsAdded += 1
                # Increase theta to atleast this cost unless we open a facility that is closer
                model.cbLazy(
                    Theta[i] >= cMin - gp.quicksum(
                        (cMin - C[i][j]) * Y[j] 
                        for j in J
                        if C[i][j] < cMin
                    )
                )
        if CutsAdded > 0 and UpperBound < round(model.cbGet(gp.GRB.Callback.MIPSOL_OBJBST)):
            print(f'Found {UpperBound}')
            model.cbSetSolution(Y, YV)
            model.cbSetSolution(Theta, ThetaV)



# Make model continious
for j in J:
    Y[j].VType= gp.GRB.CONTINUOUS
    Y[j].ub = 1

# Warm Starting - get a possible list of facilities
ExtraCon = []
for k in range(10):
    m.optimize() 

    # Set of open facilities
    FSet = {j: Y[j].x for j in J if Y[j].x >= EPS}

    # Cost of opening things and the cost of assigning things
    UpperBound = sum(F[j] * FSet[j] for j in FSet)

    CutsAdded = 0
    for i in I:
        # Get sorted list of cheapest assignments
        cSort = sorted([(C[i][j], j) for j in FSet])

        AssignCost = 0.0
        LeftToAssign = 1.0
        for (c, j) in cSort:
            Use = min(FSet[j], LeftToAssign)
            AssignCost += Use * c
            LeftToAssign -= Use
            if LeftToAssign < EPS:
                cCrit = c
                break

        UpperBound += AssignCost
        if AssignCost > Theta[i].x + EPS:
            CutsAdded += 1
            # Increase theta to atleast this cost unless we open a facility that is closer
            ExtraCon.append(m.addConstr(
                Theta[i] >= cCrit - gp.quicksum(
                    (cCrit - C[i][j]) * Y[j] 
                    for j in J
                    if C[i][j] < cCrit
                )
            ))
    print('*' * 50)
    print(k, CutsAdded, round(m.ObjVal),  UpperBound)
    print('*' * 50)


# Remove any extra constraints with slack
for c in ExtraCon:
    if abs(c.Slack) > EPS:
        m.remove(c)

# Convert back
for j in J:
    Y[j].VType = gp.GRB.BINARY




m.Params.LazyConstraints = 1 # Lazy constrain will cut off Int solutions that were previously fesiable
m.Params.BranchDir = 1 # Can possibliy speed up run time
# m.Params.Seed = 1
m.optimize(Callback)
# Out:
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1 rows, 600 columns and 300 nonzeros
# Model fingerprint: 0x0687970a
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 0 rows and 307 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 293 columns, 293 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0074900e+05   1.000000e+00   0.000000e+00      0s
#        1    3.1077800e+05   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  3.107780000e+05
# **************************************************
# 0 299 310778 456436.0
# **************************************************
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 300 rows, 600 columns and 44458 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 2e+03]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1077800e+05   5.966375e+03   0.000000e+00      0s
#      614    3.5086772e+05   0.000000e+00   0.000000e+00      0s
#
# Solved in 614 iterations and 0.01 seconds (0.04 work units)
# Optimal objective  3.508677186e+05
# **************************************************
# 1 300 350868 381809.2870057116
# **************************************************
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 600 rows, 600 columns and 70733 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 2e+03]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.5086772e+05   1.991592e+03   0.000000e+00      0s
#      580    3.7409115e+05   0.000000e+00   0.000000e+00      0s
#
# Solved in 580 iterations and 0.02 seconds (0.08 work units)
# Optimal objective  3.740911505e+05
# **************************************************
# 2 289 374091 381380.71520104236
# **************************************************
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 889 rows, 600 columns and 90313 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 2e+03]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.7409115e+05   6.101542e+02   0.000000e+00      0s
#      397    3.7759188e+05   0.000000e+00   0.000000e+00      0s
#
# Solved in 397 iterations and 0.02 seconds (0.07 work units)
# Optimal objective  3.775918800e+05
# **************************************************
# 3 226 377592 378623.7983303227
# **************************************************
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1115 rows, 600 columns and 108171 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 2e+03]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.7759188e+05   7.820054e+01   0.000000e+00      0s
#      387    3.7832517e+05   0.000000e+00   0.000000e+00      0s
#
# Solved in 387 iterations and 0.02 seconds (0.07 work units)
# Optimal objective  3.783251651e+05
# **************************************************
# 4 134 378325 378519.8504529023
# **************************************************
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1249 rows, 600 columns and 118795 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 2e+03]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.7832517e+05   1.437365e+01   0.000000e+00      0s
#      231    3.7842513e+05   0.000000e+00   0.000000e+00      0s
#
# Solved in 231 iterations and 0.01 seconds (0.05 work units)
# Optimal objective  3.784251267e+05
# **************************************************
# 5 47 378425 378446.4794751582
# **************************************************
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1296 rows, 600 columns and 122528 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 2e+03]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.7842513e+05   1.494941e+00   0.000000e+00      0s
#      105    3.7843829e+05   0.000000e+00   0.000000e+00      0s
#
# Solved in 105 iterations and 0.01 seconds (0.02 work units)
# Optimal objective  3.784382947e+05
# **************************************************
# 6 15 378438 378440.7871847182
# **************************************************
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1311 rows, 600 columns and 123819 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 2e+03]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.7843829e+05   1.676121e-01   0.000000e+00      0s
#       38    3.7843916e+05   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.784391571e+05
# **************************************************
# 7 3 378439 378439.1789449257
# **************************************************
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1314 rows, 600 columns and 124067 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 2e+03]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.7843916e+05   2.174334e-03   0.000000e+00      0s
#        6    3.7843916e+05   0.000000e+00   0.000000e+00      0s
#
# Solved in 6 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  3.784391625e+05
# **************************************************
# 8 0 378439 378439.16249736276
# **************************************************
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1314 rows, 600 columns and 124067 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 2e+03]
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  3.784391625e+05
# **************************************************
# 9 0 378439 378439.16249736276
# **************************************************
# Set parameter LazyConstraints to value 1
# Set parameter BranchDir to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# BranchDir  1
# LazyConstraints  1
#
# Optimize a model with 348 rows, 600 columns and 27886 nonzeros
# Model fingerprint: 0x4af60482
# Variable types: 300 continuous, 300 integer (300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 1e+03]
# Found 690001
# Found 462944
# Found 462944
# Found 734640
# Presolve time: 0.01s
# Presolved: 348 rows, 600 columns, 27886 nonzeros
# Variable types: 300 continuous, 300 integer (300 binary)
# Found 835170
#
# Root relaxation: objective 3.784392e+05, 136 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 378439.162    0   44          - 378439.162      -     -    0s
# Found 605092
# H    0     0                    605092.00000 378439.162  37.5%     -    0s
# Found 584060
# H    0     0                    584060.00000 378439.162  35.2%     -    0s
# Found 583103
# H    0     0                    583103.00000 378439.162  35.1%     -    0s
# Found 463154
# Found 572855
#      0     0 378444.050    0   44 583103.000 378444.050  35.1%     -    0s
# H    0     0                    462944.00000 378444.050  18.3%     -    0s
# Found 459536
# H    0     0                    459536.00000 378444.050  17.6%     -    0s
# Found 449276
# H    0     0                    449276.00000 378444.050  15.8%     -    0s
# Found 419483
# H    0     0                    419483.00000 378444.050  9.78%     -    0s
#      0     2 378444.050    0   44 419483.000 378444.050  9.78%     -    0s
# Found 410436
# H   28    48                    410436.00000 378637.910  7.75%   162    0s
# Found 394055
# H   56    65                    394055.00000 378638.037  3.91%   136    0s
# Found 393397
# H   93    74                    393397.00000 378638.037  3.75%   109    0s
# Found 393252
# H  221   107                    393252.00000 378638.037  3.72%  66.1    0s
# Found 391980
# H  247   114                    391980.00000 378642.931  3.40%  63.7    0s
# Found 391815
# H  371   129                    391815.00000 378829.910  3.31%  72.5    0s
# Found 390137
# H  486   136                    390137.00000 379078.247  2.83%  68.8    0s
#   5967   147 388018.717   21   25 390137.000 380791.705  2.40%  68.1    5s
#  12849     3     cutoff   46      390137.000 383058.825  1.81%  80.0   10s
#
# Cutting planes:
#   Lazy constraints: 1852
#
# Explored 13542 nodes (1102901 simplex iterations) in 13.31 seconds (49.08 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 390137 391815 391980 ... 459536
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.901370000000e+05, best bound 3.901370000000e+05, gap 0.0000%
#
# User-callback calls 28815, time in user-callback 0.18 sec
